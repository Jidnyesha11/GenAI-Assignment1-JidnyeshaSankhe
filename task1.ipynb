# %%
# create list of 6 products

products=["Pencil","Eraser","Pen","Scale","Sharpner","Caryons"]

print("Product List:", products)
# Out:
# Product List: ['Pencil', 'Eraser', 'Pen', 'Scale', 'Sharpner', 'Caryons']

# %%
# creating tuple

sample_products=("Water colors", 500, "Stationary")

print("Sample Product:")
print(sample_products)
# Out:
# Sample Product:
# ('Water colors', 500, 'Stationary')

# %%
# print second and last product from list

products=["Pencil","Eraser","Pen","Scale","Sharpner","Caryons"]
print(products[1])
print(products[-1])
# Out:
# Eraser
# Caryons

# %%
# append two product and update list
products.append("Chart paper")
products.append("Notebook")

print("Product list after adding:", products)
# Out:
# Product list after adding: ['Pencil', 'Eraser', 'Pen', 'Scale', 'Sharpner', 'Caryons', 'Chart paper', 'Notebook']

# %%
#convert list into tuple
print(type(sample_products))

product_list=list(sample_products)

print("List:", product_list)
# Out:
# <class 'tuple'>
# List: ['Water colors', 500, 'Stationary']

# %%
product_list[1]=960
print(product_list)
# Out:
# ['Water colors', 960, 'Stationary']

# %%
product_tuple=tuple(product_list)
print(product_tuple)
print(type(product_tuple))
# Out:
# ('Water colors', 960, 'Stationary')
# <class 'tuple'>
