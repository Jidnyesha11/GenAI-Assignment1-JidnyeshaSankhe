# %%
# create set of categories

categories_set={"electronics","stationary","furniture","apperal","appliances"}

print(categories_set)
# Out:
# {'stationary', 'appliances', 'furniture', 'electronics', 'apperal'}

# %%
categories_set.add("office")
print(categories_set)
# Out:
# {'stationary', 'appliances', 'furniture', 'office', 'electronics', 'apperal'}

# %%
# dulicates are ignored
categories_set.add("stationary")
print(categories_set)
# Out:
# {'stationary', 'appliances', 'furniture', 'office', 'electronics', 'apperal'}

# %%
# category exists

category = input("Enter category to search:")

if category in categories_set:
    print("Category Exists")
else:
    print("Category Not Found")
# Out:
# Category Exists

# %%
#total no. of unique category

print("Total Categories =",len(categories_set))
# Out:
# Total Categories = 9
